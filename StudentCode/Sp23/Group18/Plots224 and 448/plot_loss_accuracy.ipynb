# %%
#importing packages
import warnings
warnings.filterwarnings("ignore")

import pickle
import os
import pandas as pd
import random as rn
import numpy as np
import tensorflow as tf

from tqdm import tqdm
import heapq
from sklearn.utils import shuffle
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
df_baseline = pd.read_csv('baseline.csv')
df_glove = pd.read_csv('baseline_glove.csv')
# df_bert = pd.read_csv('baseline_models/100_epoch_bert_history.csv')
# df_attn = pd.read_csv('attention_model/100_epoch_attention_history.csv')
df_q_attn = pd.read_csv('question_attention.csv')
df_im_attn = pd.read_csv('image_attention.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))

ax1.plot(df_baseline['loss'])
ax1.plot(df_glove['loss'])
# ax1.plot(df_bert['loss'])
# ax1.plot(df_attn['loss'])
ax1.plot(df_q_attn['loss'])
ax1.plot(df_im_attn['loss'])
ax1.legend(['Baseline (VGG)', 'Baseline (VGG-Glove)', 'Question Attention', 'Image Attention'])
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss')
# plt.show()

ax2.plot(df_baseline['val_loss'])
ax2.plot(df_glove['val_loss'])
# ax2.plot(df_bert['val_loss'])
# ax2.plot(df_attn['val_loss'])
ax2.plot(df_q_attn['val_loss'])
ax2.plot(df_im_attn['val_loss'])
ax2.legend(['Baseline (VGG)', 'Baseline (VGG-Glove)', 'Question Attention', 'Image Attention'])
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Validation Loss')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18,6))

ax1.plot(df_baseline['accuracy'])
ax1.plot(df_glove['accuracy'])
# ax1.plot(df_bert['accuracy'])
# ax1.plot(df_attn['accuracy'])
ax1.plot(df_q_attn['accuracy'])
ax1.plot(df_im_attn['accuracy'])
ax1.legend(['Baseline (VGG)', 'Baseline (VGG-Glove)', 'Question Attention', 'Image Attention'])
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Training Loss')
# plt.show()

ax2.plot(df_baseline['val_accuracy'])
ax2.plot(df_glove['val_accuracy'])
# ax2.plot(df_bert['val_accuracy'])
# ax2.plot(df_attn['val_accuracy'])
ax2.plot(df_q_attn['val_accuracy'])
ax2.plot(df_im_attn['val_accuracy'])
ax2.legend(['Baseline (VGG)', 'Baseline (VGG-Glove)', 'Question Attention', 'Image Attention'])
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Validation Loss')
plt.show()
